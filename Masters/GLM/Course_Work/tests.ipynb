# %%
import pandas as pd 
data = pd.read_csv('expenditure.txt', sep=" ")

# %%
data.groupby("sex.hh").size()
sub_set = data[data["lab.force"] == 4]

# %%
sub_set.plot("income")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [3], line 2
#       1 sub_set.plot("income")
# ----> 2 plt.show()
#
# NameError: name 'plt' is not defined

# %%
data.groupby("hh.adults").size()
# Out:
# hh.adults
# 1    474
# 2    619
# 3     83
# 4     24
# dtype: int64
